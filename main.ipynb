# %% [markdown]
# # Data Science Accelerator Capstone Project
#
# ### Daniel Coles

# %%
import pandas as pd

# %%
df = pd.read_csv('data/Gravity_V202211.csv')
# Out:
# /tmp/ipykernel_183184/1413982463.py:1: DtypeWarning: Columns (0: empire) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/Gravity_V202211.csv')

# %%
print(f"No of Columns: {len(df.columns)}")
print(f"No of Rows: {len(df)}")
df.head()
# Out:
# No of Columns: 87
# No of Rows: 4699296
#    year country_id_o country_id_d iso3_o iso3_d  iso3num_o  iso3num_d  \
# 0  1948          ABW          ABW    ABW    ABW      533.0      533.0
# 1  1949          ABW          ABW    ABW    ABW      533.0      533.0
# 2  1950          ABW          ABW    ABW    ABW      533.0      533.0
# 3  1951          ABW          ABW    ABW    ABW      533.0      533.0
# 4  1952          ABW          ABW    ABW    ABW      533.0      533.0
#
#    country_exists_o  country_exists_d  gmt_offset_2020_o  ...  entry_time_o  \
# 0                 0                 0                NaN  ...           NaN
# 1                 0                 0                NaN  ...           NaN
# 2                 0                 0                NaN  ...           NaN
# 3                 0                 0                NaN  ...           NaN
# 4                 0                 0                NaN  ...           NaN
#
# ...

# %%
df.describe()
# Out:
#                year     iso3num_o     iso3num_d  country_exists_o  \
# count  4.699296e+06  4.680648e+06  4.680648e+06      4.699296e+06
# mean   1.984500e+03  4.381076e+02  4.381076e+02      8.776276e-01
# std    2.136001e+01  2.507368e+02  2.507368e+02      3.277154e-01
# min    1.948000e+03  4.000000e+00  4.000000e+00      0.000000e+00
# 25%    1.966000e+03  2.220000e+02  2.220000e+02      1.000000e+00
# 50%    1.984500e+03  4.400000e+02  4.400000e+02      1.000000e+00
# 75%    2.003000e+03  6.540000e+02  6.540000e+02      1.000000e+00
# max    2.021000e+03  8.940000e+02  8.940000e+02      1.000000e+00
#
#        country_exists_d  gmt_offset_2020_o  gmt_offset_2020_d  distw_harmonic  \
# count      4.699296e+06       4.124232e+06       4.124232e+06    3.627844e+06
# mean       8.776276e-01       1.553984e+00       1.553984e+00    8.602488e+03
# std        3.277154e-01       5.013345e+00       5.013345e+00    4.744739e+03
# ...

# %%
df[df['year'] == 2000]['iso3num_o']
# Out:
# 52         533.0
# 126        533.0
# 200        533.0
# 274        533.0
# 348        533.0
#            ...
# 4698978    716.0
# 4699052    716.0
# 4699126    716.0
# 4699200    716.0
# 4699274    716.0
# Name: iso3num_o, Length: 63504, dtype: float64
